# %%
import pandas as pd

df = pd.read_csv("../data/cleaned/hotel_bookings_cleaned.csv", index_col=0)

df.to_csv(
    "../data/cleaned/hotel_bookings_cleaned.csv",
    index=False
)

# %%
test = pd.read_csv("../data/cleaned/hotel_bookings_cleaned.csv")

print(test.shape)
print(test.columns[0])
# Out:
# (87395, 35)
# hotel

# %%
df.shape
# Out:
# (87395, 35)
